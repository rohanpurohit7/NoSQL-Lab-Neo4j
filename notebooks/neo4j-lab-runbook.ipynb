# %% [markdown]
# # Neo4j Lab Runbook
#
# Portfolio companion to the original lab artifact. Original documents remain preserved.
#
# ## Journey
# Graph model, sample data, pattern queries, traversal results, validation, interpretation, and modernization.
#
# ## Compatibility Lens
# Keep historical Cypher exercises intact and annotate current status separately. Compare older syntax with current Cypher guidance and current driver APIs. Review indexes and constraints using current supported patterns.
#
# ## Evidence
# Place reviewed graph screenshots beside the query or result they demonstrate.
#
# ## Validation
# Check node and relationship semantics, query intent, result correctness, and interpretation limits.
#
# ## Future State
# Add the source sequence, screenshots, synthetic graph fixtures, expected results, and current Cypher equivalents.
